# %% [markdown]
# ## <font color="maroon"><h4 align="center">Handling Missing Data - fillna, interpolate, dropna</font>

# %%
import pandas as pd
df = pd.read_csv("resources/weather_data.csv",parse_dates=['day'])
type(df.day[0])
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02       -99999          7  Sunny
# 2 2017-01-03           28     -99999   Snow
# 3 2017-01-04       -99999          7      0
# 4 2017-01-05           32     -99999   Rain
# 5 2017-01-06           31          2  Sunny
# 6 2017-01-06           34          5      0

# %%
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %% [markdown]
# ## <font color="blue">fillna</font>

# %% [markdown]
# <font color="purple">**Fill all NaN with one specific value**</font>

# %%
new_df = df.fillna(0)
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %% [markdown]
# <font color="purple">**Fill na using column names and dict**</font>

# %%
new_df = df.fillna({
        'temperature': 0,
        'windspeed': 0,
        'event': 'No Event'
    })
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %% [markdown]
# <font color="purple">**Use method to determine how to fill na values**</font>

# %%
new_df = df.fillna(method="ffill")
new_df
# Out:
# /var/folders/dc/dcgzzq296qjg6xnfmgh90l4c0000gn/T/ipykernel_9307/2534372125.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill")
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %%
new_df = df.fillna(method="bfill")
new_df
# Out:
# /var/folders/dc/dcgzzq296qjg6xnfmgh90l4c0000gn/T/ipykernel_9307/200175317.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="bfill")
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %% [markdown]
# <font color="purple">**Use of axis**</font>

# %%
new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
new_df
# Out:
# /var/folders/dc/dcgzzq296qjg6xnfmgh90l4c0000gn/T/ipykernel_9307/3318019960.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="bfill", axis="columns") # axis is either "index" or "columns"
#            temperature windspeed  event
# day
# 2017-01-01          32         6   Rain
# 2017-01-02      -99999         7  Sunny
# 2017-01-03          28    -99999   Snow
# 2017-01-04      -99999         7      0
# 2017-01-05          32    -99999   Rain
# 2017-01-06          31         2  Sunny
# 2017-01-06          34         5      0

# %% [markdown]
# <font color="purple">**limit parameter**</font>

# %%
new_df = df.fillna(method="ffill",limit=1)
new_df
# Out:
# /var/folders/dc/dcgzzq296qjg6xnfmgh90l4c0000gn/T/ipykernel_9307/2057544078.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   new_df = df.fillna(method="ffill",limit=1)
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %% [markdown]
# ### <font color="blue">interpolate</font>

# %%
new_df = df.interpolate()
new_df
# Out:
# /var/folders/dc/dcgzzq296qjg6xnfmgh90l4c0000gn/T/ipykernel_9307/812076388.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate()
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %%
new_df = df.interpolate(method="time") 
new_df
# Out:
# /var/folders/dc/dcgzzq296qjg6xnfmgh90l4c0000gn/T/ipykernel_9307/2760325171.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   new_df = df.interpolate(method="time")
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %% [markdown]
# **Notice that in above temperature on 2017-01-04 is 29 instead of 30 (in plain linear interpolate)**

# %% [markdown]
# **There are many other methods for interpolation such as quadratic, piecewise_polynomial, cubic etc.
# Just google "dataframe interpolate" to see complete documentation**

# %% [markdown]
# ### <font color="blue">dropna</font>

# %%
new_df = df.dropna()
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %%
new_df = df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %%
new_df = df.dropna(thresh=1)
new_df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-02       -99999          7  Sunny
# 2017-01-03           28     -99999   Snow
# 2017-01-04       -99999          7      0
# 2017-01-05           32     -99999   Rain
# 2017-01-06           31          2  Sunny
# 2017-01-06           34          5      0

# %% [markdown]
# ### <font color="blue">Inserting Missing Dates</font>

# %%
dt = pd.date_range("01-01-2017","01-11-2017")
idx = pd.DatetimeIndex(dt)
